# %% [markdown]
# # Phase 2 — Dataset Preprocessing
# **RealCentric Generator-Agnostic Deepfake Detection**
# SVKM AI/ML HPC Cluster — Altair Access
#
# Resizes all three datasets to 256×256 PNG.
#
# - **CelebDF V2** — real + fake face images
# - **FaceForensics++** — real + 5 manipulation methods
# - **Stable Diffusion** — fake only (512 + 768 + 1024 merged)
#
# Project root: `/data/mpstme-naman/deepfake_detection`

# %% [markdown]
# ## Step 0 — Install Requirements

# %%
# !pip install -r /data/mpstme-naman/deepfake_detection/requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (2.9.0a0+145a3a7bda.nv25.10)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 5)) (0.24.0a0+094e7af5)
# Requirement already satisfied: opencv-python-headless>=4.8.0 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 6)) (4.13.0.92)
# Requirement already satisfied: Pillow>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 7)) (12.0.0)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: scipy>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 9)) (1.16.2)
# Requirement already satisfied: PyWavelets>=1.4.0 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 11)) (1.7.2)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 12)) (3.10.7)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 13)) (6.0.3)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 14)) (4.67.1)
# Requirement already satisfied: pathlib2>=2.3.7 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 15)) (2.3.7.post1)
# Requirement already satisfied: tensorboard>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 16)) (2.20.0)
# Requirement already satisfied: transformers>=4.30.0 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from -r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (5.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (79.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (2025.9.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 11)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 12)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 12)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 12)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 12)) (25.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 12)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 12)) (2.9.0.post0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from pathlib2>=2.3.7->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.14.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 16)) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.14.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 16)) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.14.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 16)) (3.9)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.14.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 16)) (6.33.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.14.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 16)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.14.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 16)) (3.1.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (0.22.2)
# Requirement already satisfied: typer in /home/mpstme-naman/.local/lib/python3.12/site-packages (from transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (0.6.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.14.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 16)) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from typer->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/mpstme-naman/.local/lib/python3.12/site-packages (from typer->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers>=4.30.0->-r /data/mpstme-naman/deepfake_detection/requirements.txt (line 18)) (0.1.2)

# %% [markdown]
# ## Step 1 — Verify Setup

# %%
import sys
sys.path.insert(0, '/data/mpstme-naman/deepfake_detection')
from config.config_loader import print_config_summary, BASE
from pathlib import Path
print_config_summary()

print('Raw dataset check:')
for name, key in [('CelebDF V2','celebdf_v2'),('FaceForensics++','faceforensics'),('Stable Diffusion','stable_diffusion')]:
    d = BASE / 'data' / key
    n = sum(1 for _ in d.rglob('*') if _.is_file()) if d.exists() else 0
    ok = '✓' if n > 0 else '✗  NOT FOUND'
    print(f'  {ok}  {name:<22} {d}  ({n:,} files)')
# Out:
# ==============================================================
#   Configuration Summary  [CLUSTER mode]
# ==============================================================
#   Project root    : /data/mpstme-naman/deepfake_detection
#   Image size      : 256×256
#   Split           : train=0.7 val=0.15 test=0.15
#
#   Feature groups:
#     ✓  statistical            dim=4
#     ✓  frequency              dim=2
#     ✓  wavelet                dim=200
#     ✓  cnn                    dim={'clip_vit_b32': 512, 'resnet18': 512, 'efficientnet_b0': 1280}
#
#   Supervised backbone : clip_vit_b32
#   Unsupervised PCA    : 128 components
#
#   Processed data  : /data/mpstme-naman/deepfake_detection/data/processed/celebdf
#   Features        : /data/mpstme-naman/deepfake_detection/data/features
#   Checkpoints     : /data/mpstme-naman/deepfake_detection/checkpoints
#   Results         : /data/mpstme-naman/deepfake_detection/results
# ==============================================================
#
# Raw dataset check:
#   ✓  CelebDF V2             /data/mpstme-naman/deepfake_detection/data/celebdf_v2  (101,031 files)
#   ✓  FaceForensics++        /data/mpstme-naman/deepfake_detection/data/faceforensics  (191,550 files)
#   ✓  Stable Diffusion       /data/mpstme-naman/deepfake_detection/data/stable_diffusion  (9,000 files)

# %% [markdown]
# ## Step 2 — Preprocess CelebDF V2
# **~15–20 min**

# %%
# !python3 /data/mpstme-naman/deepfake_detection/src/preprocessing/preprocess.py --dataset celebdf --mode cluster
# Out:
# [2026-03-09 05:50:58] INFO  preprocess — RealCentric Deepfake Detection — Preprocessing Pipeline
# [2026-03-09 05:50:58] INFO  preprocess — Started: 2026-03-09 05:50:58
# [2026-03-09 05:50:58] INFO  preprocess —
# =======================================================
# [2026-03-09 05:50:58] INFO  preprocess —   Starting: celebdf
# [2026-03-09 05:50:58] INFO  preprocess — =======================================================
# [2026-03-09 05:50:58] INFO  preprocess — =======================================================
# [2026-03-09 05:50:58] INFO  preprocess —   CelebDF V2 Preprocessing
# [2026-03-09 05:50:58] INFO  preprocess — =======================================================
# [2026-03-09 05:50:58] INFO  preprocess —
#   [REAL]
# [2026-03-09 05:50:59] INFO  preprocess —   Processing 50360 images from real/
# [2026-03-09 05:50:59] INFO  preprocess —   Output → /data/mpstme-naman/deepfake_detection/data/processed/celebdf/real
#     [ 50360/50360]  saved=29097  skipped=21263
# [2026-03-09 05:53:38] INFO  preprocess —     real: 29097/50360 saved (57.8%)  skipped=21263 {'too_blurry': 21263}
# [2026-03-09 05:53:38] INFO  preprocess —
#   [FAKE]
# [2026-03-09 05:53:40] INFO  preprocess —   Processing 50671 images from fake/
# [2026-03-09 05:53:40] INFO  preprocess —   Output → /data/mpstme-naman/deepfake_detection/data/processed/celebdf/fake
#     [ 50671/50671]  saved=25036  skipped=25635
# [2026-03-09 05:56:07] INFO  preprocess —     fake: 25036/50671 saved (49.4%)  skipped=25635 {'too_blurry': 25635}
# =======================================================
#   Preprocessing Report — celebdf
#   2026-03-09 05:56:07
# =======================================================
#
#   [REAL]
#     Found   : 50360
#     Saved   : 29097
#     Skipped : 21263
#       too_blurry     : 21263
#
#   [FAKE]
#     Found   : 50671
#     Saved   : 25036
#     Skipped : 25635
#       too_blurry     : 25635
#
#   TOTAL SAVED   : 54133
#   TOTAL SKIPPED : 46898
# =======================================================
#
#   Report saved → /data/mpstme-naman/deepfake_detection/logs/preprocessing_report_celebdf.txt
# [2026-03-09 05:56:07] INFO  preprocess —
# All done: 2026-03-09 05:56:07

# %% [markdown]
# ## Step 3 — Preprocess FaceForensics++
# **~30–45 min**

# %%
# !python3 /data/mpstme-naman/deepfake_detection/src/preprocessing/preprocess.py --dataset faceforensics --mode cluster
# Out:
# [2026-03-09 05:56:08] INFO  preprocess — RealCentric Deepfake Detection — Preprocessing Pipeline
# [2026-03-09 05:56:08] INFO  preprocess — Started: 2026-03-09 05:56:08
# [2026-03-09 05:56:08] INFO  preprocess —
# =======================================================
# [2026-03-09 05:56:08] INFO  preprocess —   Starting: faceforensics
# [2026-03-09 05:56:08] INFO  preprocess — =======================================================
# [2026-03-09 05:56:08] INFO  preprocess — =======================================================
# [2026-03-09 05:56:08] INFO  preprocess —   FaceForensics++ Preprocessing
# [2026-03-09 05:56:08] INFO  preprocess — =======================================================
# [2026-03-09 05:56:08] INFO  preprocess —
#   [REAL]
# [2026-03-09 05:56:09] INFO  preprocess —   Processing 31949 images from real/
# [2026-03-09 05:56:09] INFO  preprocess —   Output → /data/mpstme-naman/deepfake_detection/data/processed/ff/real
#     [ 31949/31949]  saved=27308  skipped=4641
# [2026-03-09 05:59:25] INFO  preprocess —     real: 27308/31949 saved (85.5%)  skipped=4641 {'too_blurry': 4641}
# [2026-03-09 05:59:25] INFO  preprocess —
#   [FAKE] (all manipulation methods merged)
# [2026-03-09 05:59:25] INFO  preprocess —   Methods found: Deepfakes, Face2Face, FaceShifter, FaceSwap, NeuralTextures
# [2026-03-09 05:59:28] INFO  preprocess —   Processing 159601 images from fake/
# [2026-03-09 05:59:28] INFO  preprocess —   Output → /data/mpstme-naman/deepfake_detection/data/processed/ff/fake
#     [159601/159601]  saved=131743  skipped=27858
# [2026-03-09 06:15:24] INFO  preprocess —     fake: 131743/159601 saved (82.5%)  skipped=27858 {'too_blurry': 27858}
# =======================================================
#   Preprocessing Report — faceforensics
#   2026-03-09 06:15:24
# =======================================================
#
#   [REAL]
#     Found   : 31949
#     Saved   : 27308
#     Skipped : 4641
#       too_blurry     : 4641
#
#   [FAKE]
#     Found   : 159601
#     Saved   : 131743
#     Skipped : 27858
#       too_blurry     : 27858
#
#   TOTAL SAVED   : 159051
#   TOTAL SKIPPED : 32499
# =======================================================
#
#   Report saved → /data/mpstme-naman/deepfake_detection/logs/preprocessing_report_faceforensics.txt
# [2026-03-09 06:15:24] INFO  preprocess —
# All done: 2026-03-09 06:15:24

# %% [markdown]
# ## Step 4 — Preprocess Stable Diffusion
# **~5–10 min**

# %%
# !python3 /data/mpstme-naman/deepfake_detection/src/preprocessing/preprocess.py --dataset stable_diffusion --mode cluster
# Out:
# [2026-03-09 06:15:24] INFO  preprocess — RealCentric Deepfake Detection — Preprocessing Pipeline
# [2026-03-09 06:15:24] INFO  preprocess — Started: 2026-03-09 06:15:24
# [2026-03-09 06:15:24] INFO  preprocess —
# =======================================================
# [2026-03-09 06:15:24] INFO  preprocess —   Starting: stable_diffusion
# [2026-03-09 06:15:24] INFO  preprocess — =======================================================
# [2026-03-09 06:15:24] INFO  preprocess — =======================================================
# [2026-03-09 06:15:24] INFO  preprocess —   Stable Diffusion Preprocessing  [FAKE ONLY]
# [2026-03-09 06:15:24] INFO  preprocess —   (Test-only dataset — no real images)
# [2026-03-09 06:15:24] INFO  preprocess — =======================================================
# [2026-03-09 06:15:24] INFO  preprocess —
#   Subfolders found: ['1024', '512', '768']
# [2026-03-09 06:15:25] INFO  preprocess —   1024/  → 3000 images
# [2026-03-09 06:15:25] INFO  preprocess —   512/  → 3000 images
# [2026-03-09 06:15:25] INFO  preprocess —   768/  → 3000 images
# [2026-03-09 06:15:25] INFO  preprocess —
#   Total: 9000 images → /data/mpstme-naman/deepfake_detection/data/processed/sd/fake
#     [  9000/9000]  saved=9000  skipped=0
# [2026-03-09 06:19:45] INFO  preprocess —     fake: 9000/9000 saved (100.0%)  skipped=0 {}
# =======================================================
#   Preprocessing Report — stable_diffusion
#   2026-03-09 06:19:45
# =======================================================
#
#   [FAKE]
#     Found   : 9000
#     Saved   : 9000
#     Skipped : 0
#
#   TOTAL SAVED   : 9000
#   TOTAL SKIPPED : 0
# =======================================================
#
#   Report saved → /data/mpstme-naman/deepfake_detection/logs/preprocessing_report_stable_diffusion.txt
# [2026-03-09 06:19:45] INFO  preprocess —
# All done: 2026-03-09 06:19:45

# %% [markdown]
# ## Step 5 — Verify Outputs

# %%
import cv2
from pathlib import Path

BASE = Path('/data/mpstme-naman/deepfake_detection')
PROC = BASE / 'data' / 'processed'

print('Processed dataset summary:')
print('=' * 55)
for name, sub in [('CelebDF','celebdf'),('FaceForensics','ff'),('Stable Diffusion','sd')]:
    rd = PROC/sub/'real'; fd = PROC/sub/'fake'
    rn = len(list(rd.glob('*.png'))) if rd.exists() else 0
    fn = len(list(fd.glob('*.png'))) if fd.exists() else 0
    print(f'  {name:<20} real={rn:<8,} fake={fn:,}')
print('=' * 55)

print('\nSample image check:')
for s in sorted((PROC/'celebdf'/'real').glob('*.png'))[:3]:
    img = cv2.imread(str(s))
    if img is not None:
        print(f'  {s.name}  shape={img.shape}  dtype={img.dtype}')
# Out:
# Processed dataset summary:
# =======================================================
#   CelebDF              real=29,097   fake=25,036
#   FaceForensics        real=27,308   fake=131,743
#   Stable Diffusion     real=0        fake=9,000
# =======================================================
#
# Sample image check:
#   real_0000001.png  shape=(256, 256, 3)  dtype=uint8
#   real_0000002.png  shape=(256, 256, 3)  dtype=uint8
#   real_0000003.png  shape=(256, 256, 3)  dtype=uint8

# %% [markdown]
# ## ✅ Phase 2 Complete
#
# All images preprocessed to 256×256 PNG.
#
# **Next:** Open `02_feature_extraction.ipynb`
